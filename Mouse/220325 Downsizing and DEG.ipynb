# %%
# Import packages
import os, sys, glob, re, math, pickle
import phate, scprep, magic, meld
import graphtools as gt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import time,random,datetime
import networkx as nx
import scvelo as scv
from sklearn import metrics
from sklearn import model_selection
from scipy import sparse
from scipy.stats import mannwhitneyu, tiecorrect, rankdata
from statsmodels.stats.multitest import multipletests
import scanpy as sc
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import SpectralClustering, OPTICS, cluster_optics_dbscan, AgglomerativeClustering
from bbknn import bbknn
import warnings
# %matplotlib inline
# %load_ext memory_profiler

# %%
import rpy2.rinterface_lib.callbacks
import logging

from rpy2.robjects import pandas2ri
import anndata2ri

# Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython

# %%
# settings
plt.rc('font', size = 8)
plt.rc('font', family='sans serif')
plt.rcParams['pdf.fonttype']=42
plt.rcParams['ps.fonttype']=42
plt.rcParams['text.usetex']=False
plt.rcParams['legend.frameon']=False
plt.rcParams['axes.grid']=False
plt.rcParams['legend.markerscale']=0.5
sc.set_figure_params(dpi=300,dpi_save=600,
                     frameon=False,
                     fontsize=8)
plt.rcParams['savefig.dpi']=600
sc.settings.verbosity=2
sc._settings.ScanpyConfig.n_jobs=-1

# %%
# reproducibility
rs = np.random.seed(42)

# %%
# utils
def mwu(X,Y,gene_names,correction=None,debug=False) :
    '''
    Benjamini-Hochberg correction implemented. Can change to Bonferonni
    gene_names (list)
    if X,Y single gene expression array, input x.reshape(-1,1), y.reshape(-1,1)
    NOTE: get zeros sometimes because difference (p-value is so small)
    '''
    p=pd.DataFrame()
    print('Mann-Whitney U w/Benjamini/Hochberg correction\n')
    start = time.time()
    for i,g in enumerate(gene_names) :
        if i==np.round(np.quantile(np.arange(len(gene_names)),0.25)) :
            print('... 25% completed in {:.2f}-s'.format(time.time()-start))
        elif i==np.round(np.quantile(np.arange(len(gene_names)),0.5)) :
            print('... 50% completed in {:.2f}-s'.format(time.time()-start))
        elif i==np.round(np.quantile(np.arange(len(gene_names)),0.75)) :
            print('... 75% completed in {:.2f}-s'.format(time.time()-start))
        p.loc[i,'Gene']=g
        if (tiecorrect(rankdata(np.concatenate((np.asarray(X[:,i]),np.asarray(Y[:,i])))))==0) :
            if debug :
                print('P-value not calculable for {}'.format(g))
            p.loc[i,'pval']=np.nan
        else :
            _,p.loc[i,'pval']=mannwhitneyu(X[:,i],Y[:,i]) # continuity correction is True
    print('... mwu computed in {:.2f}-s\n'.format(time.time() - start))
    # ignore NaNs, since can't do a comparison on these (change numbers for correction)
    p_corrected = p.loc[p['pval'].notna(),:]
    new_pvals = multipletests(p_corrected['pval'],method='fdr_bh')
    p_corrected['pval_corrected'] = new_pvals[1]
    return p_corrected

def log2aveFC(X,Y,gene_names,AnnData=None) :
    '''not sensitivity to directionality due to subtraction
    X and Y full arrays, subsetting performed here
    `gene_names` (list): reduced list of genes to calc
    `adata` (sc.AnnData): to calculate reduced list. NOTE: assumes X,Y drawn from adata.var_names
    '''
    if not AnnData is None :
        g_idx = [i for i,g in enumerate(AnnData.var_names) if g in gene_names]
        fc=pd.DataFrame({'Gene':AnnData.var_names[g_idx],
                         'log2FC':np.log2(X[:,g_idx].mean(axis=0)) - np.log2(Y[:,g_idx].mean(axis=0))}) # returns NaN if negative value 
    else :
        fc=pd.DataFrame({'Gene':gene_names,
                         'log2FC':np.log2(X.mean(axis=0)) - np.log2(Y.mean(axis=0))})
    return fc

# %%
# fps
dfp = '/home/cl2292/project/SCA1_snRNAseq/Mouse/data/'
pfp = '/home/cl2292/project/SCA1_snRNAseq/Mouse/results/'
sc.settings.figdir = pfp

# %%
# Load Data

if True :
    start = time.time()
    backed=None # None if not
    fname='220325_WT_imp.h5ad' # for full, can maybe get away with ~300G
    # %memit wt = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))
    
if True :
    start = time.time()
    backed=None # None if not
    fname='220325_SCA1_imp.h5ad' # for full, can maybe get away with ~300G
    # %memit mut = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))
# Out:
# peak memory: 37708.37 MiB, increment: 37408.70 MiB
# loaded @220330.13:44:17
# took 35.88-s to load data
# peak memory: 74052.29 MiB, increment: 36351.14 MiB
# loaded @220330.13:44:53
# took 36.86-s to load data

# %%
print(wt.obs['timepoint'].value_counts())
print()
# print(mut.obs['timepoint'].value_counts())
# Out:
# 18wk    50640
# 30wk    31609
# 24wk    31027
# 5wk     29355
# 12wk    18910
# Name: timepoint, dtype: int64

# %%
wt5 = wt.obs.loc[wt.obs['timepoint']=='5wk', :].sample(n=18910, replace=False).index.to_list()
wt12 = wt.obs.loc[wt.obs['timepoint']=='12wk', :].sample(n=18910, replace=False).index.to_list()
wt18 = wt.obs.loc[wt.obs['timepoint']=='18wk', :].sample(n=18910, replace=False).index.to_list()
wt24 = wt.obs.loc[wt.obs['timepoint']=='24wk', :].sample(n=18910, replace=False).index.to_list()
wt30 = wt.obs.loc[wt.obs['timepoint']=='30wk', :].sample(n=18910, replace=False).index.to_list()
sample_wt = wt[(wt.obs.index.isin(wt5)|wt.obs.index.isin(wt12)|
                wt.obs.index.isin(wt18)|wt.obs.index.isin(wt24)|wt.obs.index.isin(wt30)), :]

# %%
mut5 = mut.obs.loc[mut.obs['timepoint']=='5wk', :].sample(n=18910, replace=False).index.to_list()
mut12 = mut.obs.loc[mut.obs['timepoint']=='12wk', :].sample(n=18910, replace=False).index.to_list()
mut18 = mut.obs.loc[mut.obs['timepoint']=='18wk', :].sample(n=18910, replace=False).index.to_list()
mut24 = mut.obs.loc[mut.obs['timepoint']=='24wk', :].sample(n=18910, replace=False).index.to_list()
mut30 = mut.obs.loc[mut.obs['timepoint']=='30wk', :].sample(n=18910, replace=False).index.to_list()
sample_mut = mut[(mut.obs.index.isin(mut5)|mut.obs.index.isin(mut12)|mut.obs.index.isin(mut18)|mut.obs.index.isin(mut24)|mut.obs.index.isin(mut30)), :]

# %%
sample_wt.obs['timepoint'].value_counts()
# Out:
# 30wk    18910
# 24wk    18910
# 18wk    18910
# 12wk    18910
# 5wk     18910
# Name: timepoint, dtype: int64

# %%
# save data objects
sample_wt.write(os.path.join(dfp,'220328_WT_sampling.h5ad'))
sample_mut.write(os.path.join(dfp,'220328_SCA1_sampling.h5ad'))
print('saved @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
# Out:
# saved @220328.12:19:28

# %%
# Load Data

if True :
    start = time.time()
    backed=None # None if not
    fname='220328_WT_sampling.h5ad' # for full, can maybe get away with ~300G
    # %memit wt = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))
    
if True :
    start = time.time()
    backed=None # None if not
    fname='220328_SCA1_sampling.h5ad' # for full, can maybe get away with ~300G
    # %memit mut = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))
# Out:
# peak memory: 22278.22 MiB, increment: 21978.61 MiB
# loaded @220502.10:10:47
# took 22.18-s to load data
# peak memory: 44394.02 MiB, increment: 22115.77 MiB
# loaded @220502.10:11:10
# took 22.85-s to load data

# %%
for i in wt.obs['timepoint'].unique():
    wtt = wt[wt.obs['timepoint']==i,:]
    print("WT " + i)
    print(wtt.obs['sub3'].value_counts())
    print(" ")
# Out:
# WT 5wk
# GC      14492
# MLI1      821
# OL        731
# BG        685
# AS        598
# DCN       596
# MLI2      233
# END       200
# PER       139
# OPC        96
# Z+PC       96
# MG         72
# GoC        65
# UBC        49
# Z-PC       37
# Name: sub3, dtype: int64
#
# WT 12wk
# GC      16297
# MLI1      671
# BG        436
# OL        421
# AS        322
# MLI2      213
# END        96
# Z+PC       90
# DCN        83
# PER        68
# MG         51
# OPC        50
# GoC        48
# UBC        42
# Z-PC       22
# Name: sub3, dtype: int64
#
# WT 18wk
# GC      15063
# MLI1      930
# OL        627
# BG        606
# AS        546
# MLI2      275
# DCN       229
# END       173
# Z+PC      122
# PER        91
# OPC        68
# GoC        58
# MG         56
# Z-PC       35
# UBC        31
# Name: sub3, dtype: int64
#
# WT 24wk
# GC      16408
# MLI1      626
# OL        449
# BG        390
# AS        332
# MLI2      173
# DCN       107
# END        93
# OPC        64
# MG         58
# Z+PC       50
# PER        46
# GoC        42
# Z-PC       38
# UBC        34
# Name: sub3, dtype: int64
#
# WT 30wk
# GC      15965
# MLI1      710
# BG        523
# OL        482
# AS        425
# MLI2      232
# END       193
# Z+PC       91
# MG         59
# PER        56
# GoC        47
# OPC        39
# DCN        39
# Z-PC       31
# UBC        18
# Name: sub3, dtype: int64

# %%
for i in mut.obs['timepoint'].unique():
    mutt = mut[mut.obs['timepoint']==i,:]
    print("SCA1 " + i)
    print(mutt.obs['sub3'].value_counts())
    print(" ")
# Out:
# SCA1 5wk
# GC      14584
# MLI1     1039
# BG        853
# AS        658
# OL        565
# MLI2      237
# END       235
# PER       210
# Z-PC      101
# Z+PC       94
# DCN        93
# GoC        77
# OPC        61
# MG         52
# UBC        51
# Name: sub3, dtype: int64
#
# SCA1 12wk
# GC      16143
# MLI1      769
# BG        497
# OL        438
# AS        322
# MLI2      228
# END       136
# PER        71
# Z+PC       59
# MG         51
# OPC        45
# UBC        45
# DCN        39
# GoC        37
# Z-PC       30
# Name: sub3, dtype: int64
#
# SCA1 18wk
# GC      15301
# MLI1      906
# AS        571
# OL        568
# BG        564
# MLI2      253
# END       218
# PER        97
# Z-PC       93
# MG         85
# DCN        59
# OPC        58
# GoC        51
# Z+PC       47
# UBC        39
# Name: sub3, dtype: int64
#
# SCA1 24wk
# GC      16109
# MLI1      607
# OL        494
# BG        450
# AS        414
# MLI2      189
# DCN       172
# END       120
# MG         70
# PER        66
# OPC        56
# Z+PC       52
# Z-PC       39
# UBC        38
# GoC        34
# Name: sub3, dtype: int64
#
# SCA1 30wk
# GC      15620
# MLI1      835
# BG        558
# OL        545
# AS        473
# MLI2      250
# END       202
# Z+PC       62
# PER        58
# DCN        58
# MG         57
# GoC        55
# Z-PC       51
# OPC        49
# UBC        37
# Name: sub3, dtype: int64

# %%
## EMD; SUB4, IMP, Sampling

if True :
    dge_grandtotal = time.time()
    group='sub4'
    fname = '220328_mouse_imp_samp' 
    dge = pd.DataFrame()
    for t in ['5wk','12wk','18wk','24wk','30wk'] :
        print('Evaluating {}'.format(t))
        t_total = time.time()
        dge_total = time.time()
        start_t=time.time()
        
        # up down dichotomy
        print('\n--------')
        print('...')
        print('--------\n')
#        dge = pd.DataFrame()
        for i in wt.obs[group].unique() :
            start = time.time()
            print('\n{}, WT vs SCA1'.format(i))
            print('----')
            X = wt[((wt.obs[group]==i) & (wt.obs['timepoint']==t)), :].layers['imputed']
            Y = mut[((mut.obs[group]==i) & (mut.obs['timepoint']==t)), :].layers['imputed']
            

            X = np.asarray(X)
            Y = np.asarray(Y)
        
            print('    Ncells in X:{}'.format(X.shape[0]))
            print('    Ncells in Y:{}\n'.format(Y.shape[0]))            
            
            emd = scprep.stats.differential_expression(X,Y,
                                                       measure = 'emd',
                                                       direction='both',
                                                       gene_names=wt.var_names,
                                                       n_jobs=-1)
            
            # mann-whitney u, corrected p-values
            p = mwu(X,Y,wt.var_names)
            emd['Gene']=emd.index
            emd=emd.drop(columns='rank')
            fc = log2aveFC(Y,X,wt.var_names.to_list())
            gene_mismatch = fc['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                fc = fc.loc[gene_mismatch,:]
                warnings.warn('Warning: {} genes dropped due to p-val NA.'.format((gene_mismatch==False).sum()))
            dt = pd.merge(p,fc,how='left',on="Gene")
            gene_mismatch = emd['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                emd = emd.loc[gene_mismatch,:]
            dt = pd.merge(dt,emd,how='left',on='Gene')
            dt['Cell type']=[i]*dt.shape[0]
            dt['timepoint']=[str(t)]*dt.shape[0]
            dt['nlog10pvalcorrected']=(-1)*np.log10(dt['pval_corrected'])
            dge = dge.append(dt, ignore_index=True)
            print('... computed in {:.2f}-s'.format(time.time()-start))
        print('\nFinished timepoint {} in {:.2f}-min'.format(t,(time.time()-start_t)/60))  
    dgeup = dge.loc[dge['emd']>0,:] # take only 'up' (switch for down)
    dgedown = dge.loc[dge['emd']<0,:] # take only 'down'
    dgeup.to_csv(os.path.join(pfp,'dge_'+fname+'_WTup.csv'),index=False)
    dgedown.to_csv(os.path.join(pfp,'dge_'+fname+'_WTdown.csv'),index=False)
        

    print('DGE finished in {:.2f}-min'.format((time.time()-dge_grandtotal)/60))
# Out:
# Evaluating 5wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:685
#     Ncells in Y:853
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 18.29-s
# ... 50% completed in 39.51-s
# ... 75% completed in 64.94-s
# ... mwu computed in 94.23-s
#
# ... computed in 105.32-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:14492
#     Ncells in Y:14584
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 102.50-s
# ... 50% completed in 210.74-s
# ... 75% completed in 325.92-s
# ... mwu computed in 446.98-s
#
# ... computed in 519.94-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:731
#     Ncells in Y:565
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.99-s
# ... 50% completed in 39.03-s
# ... 75% completed in 64.12-s
# ... mwu computed in 93.49-s
#
# ... computed in 101.73-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:598
#     Ncells in Y:658
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.56-s
# ... 50% completed in 38.32-s
# ... 75% completed in 63.39-s
# ... mwu computed in 92.58-s
#
# ... computed in 97.88-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:596
#     Ncells in Y:93
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.75-s
# ... 50% completed in 36.59-s
# ... 75% completed in 60.48-s
# ... mwu computed in 88.54-s
#
# ... computed in 93.19-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:72
#     Ncells in Y:52
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.18-s
# ... 50% completed in 33.42-s
# ... 75% completed in 55.45-s
# ... mwu computed in 81.34-s
#
# ... computed in 84.75-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:233
#     Ncells in Y:237
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.70-s
# ... 50% completed in 34.41-s
# ... 75% completed in 56.79-s
# ... mwu computed in 82.86-s
#
# ... computed in 86.78-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:821
#     Ncells in Y:1039
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 19.22-s
# ... 50% completed in 41.68-s
# ... 75% completed in 68.07-s
# ... mwu computed in 98.57-s
#
# ... computed in 105.47-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:49
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.09-s
# ... 50% completed in 33.15-s
# ... 75% completed in 54.88-s
# ... mwu computed in 80.32-s
#
# ... computed in 83.68-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:139
#     Ncells in Y:210
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.32-s
# ... 50% completed in 33.70-s
# ... 75% completed in 56.13-s
# ... mwu computed in 82.26-s
#
# ... computed in 86.20-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:200
#     Ncells in Y:235
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.91-s
# ... 50% completed in 34.70-s
# ... 75% completed in 57.56-s
# ... mwu computed in 83.96-s
#
# ... computed in 87.87-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:96
#     Ncells in Y:61
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.33-s
# ... 50% completed in 33.66-s
# ... 75% completed in 56.30-s
# ... mwu computed in 83.23-s
#
# ... computed in 86.83-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:65
#     Ncells in Y:77
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.21-s
# ... 50% completed in 33.55-s
# ... 75% completed in 55.90-s
# ... mwu computed in 81.92-s
#
# ... computed in 85.35-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:133
#     Ncells in Y:195
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.72-s
# ... 50% completed in 34.44-s
# ... 75% completed in 57.36-s
# ... mwu computed in 84.22-s
#
# ... computed in 87.92-s
#
# Finished timepoint 5wk in 28.55-min
# Evaluating 12wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:436
#     Ncells in Y:497
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.18-s
# ... 50% completed in 37.47-s
# ... 75% completed in 61.98-s
# ... mwu computed in 90.66-s
#
# ... computed in 95.91-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:16297
#     Ncells in Y:16143
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 127.14-s
# ... 50% completed in 259.40-s
# ... 75% completed in 397.66-s
# ... mwu computed in 542.51-s
#
# ... computed in 633.60-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:421
#     Ncells in Y:438
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.76-s
# ... 50% completed in 36.42-s
# ... 75% completed in 59.89-s
# ... mwu computed in 87.25-s
#
# ... computed in 94.81-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:322
#     Ncells in Y:322
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.21-s
# ... 50% completed in 35.31-s
# ... 75% completed in 58.32-s
# ... mwu computed in 85.15-s
#
# ... computed in 89.46-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:83
#     Ncells in Y:39
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.40-s
# ... 50% completed in 33.80-s
# ... 75% completed in 56.20-s
# ... mwu computed in 82.84-s
#
# ... computed in 86.33-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:51
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.77-s
# ... 50% completed in 32.57-s
# ... 75% completed in 54.40-s
# ... mwu computed in 80.03-s
#
# ... computed in 83.62-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:213
#     Ncells in Y:228
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.05-s
# ... 50% completed in 35.21-s
# ... 75% completed in 58.37-s
# ... mwu computed in 85.67-s
#
# ... computed in 89.62-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:671
#     Ncells in Y:769
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 18.39-s
# ... 50% completed in 39.92-s
# ... 75% completed in 65.39-s
# ... mwu computed in 94.92-s
#
# ... computed in 101.24-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:42
#     Ncells in Y:45
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.71-s
# ... 50% completed in 32.58-s
# ... 75% completed in 54.11-s
# ... mwu computed in 79.32-s
#
# ... computed in 82.80-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:68
#     Ncells in Y:71
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.47-s
# ... 50% completed in 33.96-s
# ... 75% completed in 56.68-s
# ... mwu computed in 82.97-s
#
# ... computed in 86.62-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:96
#     Ncells in Y:136
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.54-s
# ... 50% completed in 34.03-s
# ... 75% completed in 56.84-s
# ... mwu computed in 83.63-s
#
# ... computed in 87.29-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:50
#     Ncells in Y:45
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.05-s
# ... 50% completed in 33.25-s
# ... 75% completed in 55.42-s
# ... mwu computed in 81.86-s
#
# ... computed in 85.29-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:48
#     Ncells in Y:37
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.16-s
# ... 50% completed in 33.37-s
# ... 75% completed in 55.62-s
# ... mwu computed in 81.81-s
#
# ... computed in 85.43-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:112
#     Ncells in Y:89
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.13-s
# ... 50% completed in 33.16-s
# ... 75% completed in 55.51-s
# ... mwu computed in 81.51-s
#
# ... computed in 85.10-s
#
# Finished timepoint 12wk in 29.79-min
# Evaluating 18wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:606
#     Ncells in Y:564
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.31-s
# ... 50% completed in 37.70-s
# ... 75% completed in 62.24-s
# ... mwu computed in 90.73-s
#
# ... computed in 95.98-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:15063
#     Ncells in Y:15301
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 113.43-s
# ... 50% completed in 233.30-s
# ... 75% completed in 359.14-s
# ... mwu computed in 490.98-s
#
# ... computed in 571.30-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:627
#     Ncells in Y:568
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.69-s
# ... 50% completed in 38.60-s
# ... 75% completed in 63.59-s
# ... mwu computed in 92.83-s
#
# ... computed in 100.98-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:546
#     Ncells in Y:571
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.13-s
# ... 50% completed in 37.37-s
# ... 75% completed in 61.80-s
# ... mwu computed in 89.92-s
# ... computed in 95.15-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:229
#     Ncells in Y:59
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.78-s
# ... 50% completed in 34.61-s
# ... 75% completed in 57.31-s
# ... mwu computed in 83.39-s
#
# ... computed in 87.11-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:56
#     Ncells in Y:85
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.37-s
# ... 50% completed in 33.80-s
# ... 75% completed in 56.17-s
# ... mwu computed in 82.82-s
#
# ... computed in 86.59-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:275
#     Ncells in Y:253
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.78-s
# ... 50% completed in 34.56-s
# ... 75% completed in 57.35-s
# ... mwu computed in 83.58-s
#
# ... computed in 87.74-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:930
#     Ncells in Y:906
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 18.73-s
# ... 50% completed in 40.62-s
# ... 75% completed in 66.56-s
# ... mwu computed in 96.40-s
#
# ... computed in 103.27-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:31
#     Ncells in Y:39
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.03-s
# ... 50% completed in 33.14-s
# ... 75% completed in 55.17-s
# ... mwu computed in 81.06-s
#
# ... computed in 84.50-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:91
#     Ncells in Y:97
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.04-s
# ... 50% completed in 33.07-s
# ... 75% completed in 54.90-s
# ... mwu computed in 80.42-s
#
# ... computed in 83.99-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:173
#     Ncells in Y:218
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.72-s
# ... 50% completed in 34.56-s
# ... 75% completed in 57.37-s
# ... mwu computed in 84.54-s
#
# ... computed in 88.51-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:68
#     Ncells in Y:58
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.24-s
# ... 50% completed in 33.37-s
# ... 75% completed in 55.49-s
# ... mwu computed in 80.52-s
#
# ... computed in 83.99-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:58
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.87-s
# ... 50% completed in 32.95-s
# ... 75% completed in 54.54-s
# ... mwu computed in 79.87-s
#
# ... computed in 83.45-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:157
#     Ncells in Y:140
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.58-s
# ... 50% completed in 34.29-s
# ... 75% completed in 56.86-s
# ... mwu computed in 83.08-s
#
# ... computed in 86.93-s
#
# Finished timepoint 18wk in 28.99-min
# Evaluating 24wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:390
#     Ncells in Y:450
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.85-s
# ... 50% completed in 36.78-s
# ... 75% completed in 61.02-s
# ... mwu computed in 89.41-s
#
# ... computed in 94.50-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:16408
#     Ncells in Y:16109
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 121.71-s
# ... 50% completed in 249.55-s
# ... 75% completed in 381.90-s
# ... mwu computed in 520.51-s
#
# ... computed in 607.10-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:449
#     Ncells in Y:494
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.19-s
# ... 50% completed in 37.41-s
# ... 75% completed in 61.90-s
# ... mwu computed in 90.48-s
#
# ... computed in 98.33-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:332
#     Ncells in Y:414
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.32-s
# ... 50% completed in 35.67-s
# ... 75% completed in 59.07-s
# ... mwu computed in 86.55-s
#
# ... computed in 91.37-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:107
#     Ncells in Y:172
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.76-s
# ... 50% completed in 34.76-s
# ... 75% completed in 57.50-s
# ... mwu computed in 84.37-s
#
# ... computed in 88.11-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:58
#     Ncells in Y:70
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.94-s
# ... 50% completed in 32.85-s
# ... 75% completed in 54.72-s
# ... mwu computed in 80.49-s
#
# ... computed in 84.11-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:173
#     Ncells in Y:189
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.91-s
# ... 50% completed in 34.68-s
# ... 75% completed in 57.67-s
# ... mwu computed in 84.59-s
#
# ... computed in 88.42-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:626
#     Ncells in Y:607
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.51-s
# ... 50% completed in 37.91-s
# ... 75% completed in 62.34-s
# ... mwu computed in 90.89-s
#
# ... computed in 96.80-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:34
#     Ncells in Y:38
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.98-s
# ... 50% completed in 32.98-s
# ... 75% completed in 55.10-s
# ... mwu computed in 81.08-s
#
# ... computed in 84.86-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:46
#     Ncells in Y:66
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.84-s
# ... 50% completed in 32.75-s
# ... 75% completed in 54.52-s
# ... mwu computed in 80.14-s
#
# ... computed in 83.74-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:93
#     Ncells in Y:120
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.50-s
# ... 50% completed in 34.02-s
# ... 75% completed in 56.60-s
# ... mwu computed in 83.22-s
#
# ... computed in 87.17-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:64
#     Ncells in Y:56
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.09-s
# ... 50% completed in 33.27-s
# ... 75% completed in 55.17-s
# ... mwu computed in 80.81-s
#
# ... computed in 84.46-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:42
#     Ncells in Y:34
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.10-s
# ... 50% completed in 33.20-s
# ... 75% completed in 55.23-s
# ... mwu computed in 81.25-s
#
# ... computed in 84.90-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:88
#     Ncells in Y:91
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.40-s
# ... 50% completed in 33.82-s
# ... 75% completed in 56.47-s
# ... mwu computed in 83.13-s
#
# ... computed in 86.81-s
#
# Finished timepoint 24wk in 29.34-min
# Evaluating 30wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:523
#     Ncells in Y:558
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.91-s
# ... 50% completed in 36.97-s
# ... 75% completed in 61.03-s
# ... mwu computed in 88.70-s
#
# ... computed in 94.29-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:15965
#     Ncells in Y:15620
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 110.10-s
# ... 50% completed in 226.20-s
# ... 75% completed in 348.78-s
# ... mwu computed in 476.45-s
#
# ... computed in 556.14-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:482
#     Ncells in Y:545
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 17.25-s
# ... 50% completed in 37.42-s
# ... 75% completed in 61.73-s
# ... mwu computed in 90.05-s
#
# ... computed in 97.78-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:425
#     Ncells in Y:473
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.98-s
# ... 50% completed in 37.19-s
# ... 75% completed in 61.54-s
# ... mwu computed in 90.06-s
#
# ... computed in 95.41-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:39
#     Ncells in Y:58
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.37-s
# ... 50% completed in 33.72-s
# ... 75% completed in 56.06-s
# ... mwu computed in 81.71-s
#
# ... computed in 85.35-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:59
#     Ncells in Y:57
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.25-s
# ... 50% completed in 33.53-s
# ... 75% completed in 55.90-s
# ... mwu computed in 82.40-s
#
# ... computed in 86.11-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:232
#     Ncells in Y:250
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.68-s
# ... 50% completed in 34.44-s
# ... 75% completed in 57.18-s
# ... mwu computed in 83.42-s
#
# ... computed in 88.01-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:710
#     Ncells in Y:835
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 19.28-s
# ... 50% completed in 40.96-s
# ... 75% completed in 67.38-s
# ... mwu computed in 97.40-s
#
# ... computed in 104.14-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:18
#     Ncells in Y:37
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.06-s
# ... 50% completed in 32.96-s
# ... 75% completed in 54.88-s
# ... mwu computed in 80.56-s
#
# ... computed in 84.47-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:56
#     Ncells in Y:58
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.88-s
# ... 50% completed in 32.86-s
# ... 75% completed in 54.75-s
# ... mwu computed in 80.29-s
#
# ... computed in 83.98-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:193
#     Ncells in Y:202
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.70-s
# ... 50% completed in 34.60-s
# ... 75% completed in 57.40-s
# ... mwu computed in 84.20-s
#
# ... computed in 88.48-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:39
#     Ncells in Y:49
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.93-s
# ... 50% completed in 32.82-s
# ... 75% completed in 55.00-s
# ... mwu computed in 81.07-s
#
# ... computed in 84.68-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:47
#     Ncells in Y:55
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.88-s
# ... 50% completed in 32.83-s
# ... 75% completed in 54.46-s
# ... mwu computed in 79.89-s
#
# ... computed in 83.56-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:122
#     Ncells in Y:113
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.14-s
# ... 50% completed in 33.31-s
# ... 75% completed in 55.38-s
# ... mwu computed in 81.44-s
#
# ... computed in 85.42-s
#
# Finished timepoint 30wk in 28.63-min
# DGE finished in 145.58-min

# %%
## EMD; SUB4, No IMP, Sampling

if True :
    dge_grandtotal = time.time()
    group='sub4'
    fname = '220415_mouse_no_imp_samp' 
    dge = pd.DataFrame()
    for t in ['5wk','12wk','18wk','24wk','30wk'] :
        print('Evaluating {}'.format(t))
        t_total = time.time()
        dge_total = time.time()
        start_t=time.time()
        
        # up down dichotomy
        print('\n--------')
        print('...')
        print('--------\n')
#        dge = pd.DataFrame()
        for i in wt.obs[group].unique() :
            start = time.time()
            print('\n{}, WT vs SCA1'.format(i))
            print('----')
            X = wt.X[((wt.obs[group]==i) & (wt.obs['timepoint']==t)), :]
            Y = mut.X[((mut.obs[group]==i) & (mut.obs['timepoint']==t)), :]
            
            if sparse.issparse(X):
                X = X.todense()
            if sparse.issparse(Y):
                Y = Y.todense()
                
            X = np.asarray(X)
            Y = np.asarray(Y)
        
            print('    Ncells in X:{}'.format(X.shape[0]))
            print('    Ncells in Y:{}\n'.format(Y.shape[0]))            
            
            emd = scprep.stats.differential_expression(X,Y,
                                                       measure = 'emd',
                                                       direction='both',
                                                       gene_names=wt.var_names,
                                                       n_jobs=-1)
            
            # mann-whitney u, corrected p-values
            p = mwu(X,Y,wt.var_names)
            emd['Gene']=emd.index
            emd=emd.drop(columns='rank')
            fc = log2aveFC(Y,X,wt.var_names.to_list())
            gene_mismatch = fc['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                fc = fc.loc[gene_mismatch,:]
                warnings.warn('Warning: {} genes dropped due to p-val NA.'.format((gene_mismatch==False).sum()))
            dt = pd.merge(p,fc,how='left',on="Gene")
            gene_mismatch = emd['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                emd = emd.loc[gene_mismatch,:]
            dt = pd.merge(dt,emd,how='left',on='Gene')
            dt['Cell type']=[i]*dt.shape[0]
            dt['timepoint']=[str(t)]*dt.shape[0]
            dt['nlog10pvalcorrected']=(-1)*np.log10(dt['pval_corrected'])
            dge = dge.append(dt, ignore_index=True)
            print('... computed in {:.2f}-s'.format(time.time()-start))
        print('\nFinished timepoint {} in {:.2f}-min'.format(t,(time.time()-start_t)/60))  
    dgeup = dge.loc[dge['emd']>0,:] # take only 'up' (switch for down)
    dgedown = dge.loc[dge['emd']<0,:] # take only 'down'
    dgeup.to_csv(os.path.join(pfp,'dge_'+fname+'_WTup.csv'),index=False)
    dgedown.to_csv(os.path.join(pfp,'dge_'+fname+'_WTdown.csv'),index=False)
        

    print('DGE finished in {:.2f}-min'.format((time.time()-dge_grandtotal)/60))
# Out:
# Evaluating 5wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:685
#     Ncells in Y:853
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.13-s
# ... 50% completed in 35.09-s
# ... 75% completed in 57.91-s
# ... mwu computed in 84.28-s
#
# ... computed in 92.36-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:14492
#     Ncells in Y:14584
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 38.50-s
# ... 50% completed in 79.24-s
# ... 75% completed in 124.24-s
# ... mwu computed in 172.90-s
#
# ... computed in 206.36-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:731
#     Ncells in Y:565
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.04-s
# ... 50% completed in 34.92-s
# ... 75% completed in 57.63-s
# ... mwu computed in 83.96-s
#
# ... computed in 88.27-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:598
#     Ncells in Y:658
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.99-s
# ... 50% completed in 34.82-s
# ... 75% completed in 57.46-s
# ... mwu computed in 83.64-s
#
# ... computed in 87.69-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:596
#     Ncells in Y:93
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.76-s
# ... 50% completed in 34.36-s
# ... 75% completed in 56.75-s
# ... mwu computed in 82.66-s
#
# ... computed in 86.37-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:72
#     Ncells in Y:52
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.59-s
# ... 50% completed in 32.06-s
# ... 75% completed in 53.33-s
# ... mwu computed in 78.15-s
#
# ... computed in 81.17-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:233
#     Ncells in Y:237
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.20-s
# ... 50% completed in 33.31-s
# ... 75% completed in 55.18-s
# ... mwu computed in 80.52-s
#
# ... computed in 83.87-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:821
#     Ncells in Y:1039
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.85-s
# ... 50% completed in 36.52-s
# ... 75% completed in 60.03-s
# ... mwu computed in 87.03-s
#
# ... computed in 91.87-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:49
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.63-s
# ... 50% completed in 32.21-s
# ... 75% completed in 53.70-s
# ... mwu computed in 78.62-s
#
# ... computed in 81.65-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:139
#     Ncells in Y:210
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.06-s
# ... 50% completed in 33.02-s
# ... 75% completed in 54.80-s
# ... mwu computed in 80.08-s
#
# ... computed in 83.54-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:200
#     Ncells in Y:235
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.27-s
# ... 50% completed in 33.49-s
# ... 75% completed in 55.48-s
# ... mwu computed in 80.88-s
#
# ... computed in 84.25-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:96
#     Ncells in Y:61
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.72-s
# ... 50% completed in 32.33-s
# ... 75% completed in 53.82-s
# ... mwu computed in 78.85-s
#
# ... computed in 82.16-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:65
#     Ncells in Y:77
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.88-s
# ... 50% completed in 32.63-s
# ... 75% completed in 54.19-s
# ... mwu computed in 79.37-s
#
# ... computed in 82.45-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:133
#     Ncells in Y:195
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.29-s
# ... 50% completed in 33.47-s
# ... 75% completed in 55.47-s
# ... mwu computed in 81.02-s
#
# ... computed in 84.36-s
#
# Finished timepoint 5wk in 21.94-min
# Evaluating 12wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:436
#     Ncells in Y:497
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.73-s
# ... 50% completed in 34.35-s
# ... 75% completed in 56.81-s
# ... mwu computed in 82.82-s
#
# ... computed in 86.70-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:16297
#     Ncells in Y:16143
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 40.86-s
# ... 50% completed in 83.86-s
# ... 75% completed in 131.21-s
# ... mwu computed in 182.31-s
#
# ... computed in 218.10-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:421
#     Ncells in Y:438
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.59-s
# ... 50% completed in 34.08-s
# ... 75% completed in 56.29-s
# ... mwu computed in 82.14-s
#
# ... computed in 85.90-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:322
#     Ncells in Y:322
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.51-s
# ... 50% completed in 33.87-s
# ... 75% completed in 56.21-s
# ... mwu computed in 82.11-s
#
# ... computed in 85.69-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:83
#     Ncells in Y:39
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.95-s
# ... 50% completed in 32.76-s
# ... 75% completed in 54.39-s
# ... mwu computed in 79.65-s
#
# ... computed in 82.93-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:51
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.56-s
# ... 50% completed in 32.00-s
# ... 75% completed in 53.28-s
# ... mwu computed in 78.04-s
#
# ... computed in 81.21-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:213
#     Ncells in Y:228
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.32-s
# ... 50% completed in 33.47-s
# ... 75% completed in 55.43-s
# ... mwu computed in 80.89-s
#
# ... computed in 84.26-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:671
#     Ncells in Y:769
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.43-s
# ... 50% completed in 35.74-s
# ... 75% completed in 58.84-s
# ... mwu computed in 85.53-s
#
# ... computed in 89.98-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:42
#     Ncells in Y:45
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.60-s
# ... 50% completed in 32.06-s
# ... 75% completed in 53.34-s
# ... mwu computed in 78.15-s
#
# ... computed in 81.24-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:68
#     Ncells in Y:71
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.81-s
# ... 50% completed in 32.51-s
# ... 75% completed in 53.98-s
# ... mwu computed in 79.03-s
#
# ... computed in 82.33-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:96
#     Ncells in Y:136
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.99-s
# ... 50% completed in 32.83-s
# ... 75% completed in 54.46-s
# ... mwu computed in 79.62-s
#
# ... computed in 82.86-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:50
#     Ncells in Y:45
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.65-s
# ... 50% completed in 32.15-s
# ... 75% completed in 53.50-s
# ... mwu computed in 78.28-s
#
# ... computed in 81.50-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:48
#     Ncells in Y:37
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.82-s
# ... 50% completed in 32.54-s
# ... 75% completed in 54.06-s
# ... mwu computed in 79.20-s
#
# ... computed in 82.31-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:112
#     Ncells in Y:89
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.09-s
# ... 50% completed in 33.08-s
# ... 75% completed in 54.84-s
# ... mwu computed in 80.11-s
#
# ... computed in 83.34-s
#
# Finished timepoint 12wk in 21.81-min
# Evaluating 18wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:606
#     Ncells in Y:564
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.83-s
# ... 50% completed in 34.46-s
# ... 75% completed in 56.85-s
# ... mwu computed in 82.82-s
#
# ... computed in 86.97-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:15063
#     Ncells in Y:15301
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 37.74-s
# ... 50% completed in 77.80-s
# ... 75% completed in 122.04-s
# ... mwu computed in 169.91-s
#
# ... computed in 202.56-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:627
#     Ncells in Y:568
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.67-s
# ... 50% completed in 34.20-s
# ... 75% completed in 56.59-s
# ... mwu computed in 82.48-s
#
# ... computed in 86.65-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:546
#     Ncells in Y:571
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.82-s
# ... 50% completed in 34.56-s
# ... 75% completed in 57.06-s
# ... mwu computed in 83.13-s
#
# ... computed in 87.15-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:229
#     Ncells in Y:59
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.09-s
# ... 50% completed in 33.04-s
# ... 75% completed in 54.78-s
# ... mwu computed in 80.05-s
#
# ... computed in 83.37-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:56
#     Ncells in Y:85
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.63-s
# ... 50% completed in 32.14-s
# ... 75% completed in 53.54-s
# ... mwu computed in 78.49-s
#
# ... computed in 81.79-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:275
#     Ncells in Y:253
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.25-s
# ... 50% completed in 33.37-s
# ... 75% completed in 55.28-s
# ... mwu computed in 80.66-s
#
# ... computed in 84.15-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:930
#     Ncells in Y:906
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.62-s
# ... 50% completed in 36.09-s
# ... 75% completed in 59.38-s
# ... mwu computed in 86.28-s
#
# ... computed in 91.10-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:31
#     Ncells in Y:39
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.42-s
# ... 50% completed in 31.71-s
# ... 75% completed in 52.83-s
# ... mwu computed in 77.47-s
#
# ... computed in 80.61-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:91
#     Ncells in Y:97
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.84-s
# ... 50% completed in 32.55-s
# ... 75% completed in 54.03-s
# ... mwu computed in 79.10-s
#
# ... computed in 82.47-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:173
#     Ncells in Y:218
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.10-s
# ... 50% completed in 33.06-s
# ... 75% completed in 54.81-s
# ... mwu computed in 80.10-s
#
# ... computed in 83.45-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:68
#     Ncells in Y:58
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.58-s
# ... 50% completed in 32.05-s
# ... 75% completed in 53.35-s
# ... mwu computed in 78.19-s
#
# ... computed in 81.34-s
#
# GoC, WT vs SCA1
# ----
#     Ncells in X:58
#     Ncells in Y:51
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.67-s
# ... 50% completed in 32.22-s
# ... 75% completed in 53.50-s
# ... mwu computed in 78.25-s
#
# ... computed in 81.53-s
#
# PC, WT vs SCA1
# ----
#     Ncells in X:157
#     Ncells in Y:140
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.07-s
# ... 50% completed in 33.03-s
# ... 75% completed in 54.76-s
# ... mwu computed in 80.01-s
#
# ... computed in 83.32-s
#
# Finished timepoint 18wk in 21.61-min
# Evaluating 24wk
#
# --------
# ...
# --------
#
#
# BG, WT vs SCA1
# ----
#     Ncells in X:390
#     Ncells in Y:450
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.51-s
# ... 50% completed in 33.86-s
# ... 75% completed in 56.01-s
# ... mwu computed in 81.68-s
#
# ... computed in 85.58-s
#
# GC, WT vs SCA1
# ----
#     Ncells in X:16408
#     Ncells in Y:16109
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 40.03-s
# ... 50% completed in 82.15-s
# ... 75% completed in 128.58-s
# ... mwu computed in 178.76-s
#
# ... computed in 213.94-s
#
# OL, WT vs SCA1
# ----
#     Ncells in X:449
#     Ncells in Y:494
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.61-s
# ... 50% completed in 34.06-s
# ... 75% completed in 56.34-s
# ... mwu computed in 82.15-s
#
# ... computed in 86.03-s
#
# AS, WT vs SCA1
# ----
#     Ncells in X:332
#     Ncells in Y:414
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.51-s
# ... 50% completed in 33.91-s
# ... 75% completed in 56.10-s
# ... mwu computed in 81.91-s
#
# ... computed in 85.71-s
#
# DCN, WT vs SCA1
# ----
#     Ncells in X:107
#     Ncells in Y:172
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.21-s
# ... 50% completed in 33.26-s
# ... 75% completed in 55.09-s
# ... mwu computed in 80.40-s
#
# ... computed in 83.76-s
#
# MG, WT vs SCA1
# ----
#     Ncells in X:58
#     Ncells in Y:70
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.59-s
# ... 50% completed in 32.06-s
# ... 75% completed in 53.34-s
# ... mwu computed in 78.03-s
#
# ... computed in 81.31-s
#
# MLI2, WT vs SCA1
# ----
#     Ncells in X:173
#     Ncells in Y:189
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.07-s
# ... 50% completed in 32.98-s
# ... 75% completed in 54.61-s
# ... mwu computed in 79.72-s
#
# ... computed in 83.05-s
#
# MLI1, WT vs SCA1
# ----
#     Ncells in X:626
#     Ncells in Y:607
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 16.09-s
# ... 50% completed in 35.04-s
# ... 75% completed in 57.81-s
# ... mwu computed in 84.14-s
#
# ... computed in 88.41-s
#
# UBC, WT vs SCA1
# ----
#     Ncells in X:34
#     Ncells in Y:38
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.44-s
# ... 50% completed in 31.75-s
# ... 75% completed in 52.83-s
# ... mwu computed in 77.44-s
#
# ... computed in 80.56-s
#
# PER, WT vs SCA1
# ----
#     Ncells in X:46
#     Ncells in Y:66
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.69-s
# ... 50% completed in 32.32-s
# ... 75% completed in 53.69-s
# ... mwu computed in 78.53-s
#
# ... computed in 81.68-s
#
# END, WT vs SCA1
# ----
#     Ncells in X:93
#     Ncells in Y:120
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.86-s
# ... 50% completed in 32.56-s
# ... 75% completed in 54.03-s
# ... mwu computed in 78.93-s
#
# ... computed in 82.33-s
#
# OPC, WT vs SCA1
# ----
#     Ncells in X:64
#     Ncells in Y:56
#
# Mann-Whitney U w/Benjamini/Hochberg correction

# %%
# Load Data

if True :
    start = time.time()
    backed=None # None if not
    fname='220325_WT_imp.h5ad' # for full, can maybe get away with ~300G
    # %memit wtt = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))
    
if True :
    start = time.time()
    backed=None # None if not
    fname='220325_SCA1_imp.h5ad' # for full, can maybe get away with ~300G
    # %memit mutt = sc.read_h5ad(os.path.join(dfp,fname),backed=backed)
    print('loaded @'+datetime.datetime.now().strftime('%y%m%d.%H:%M:%S'))
    print('took {:.2f}-s to load data'.format(time.time()-start))

# %%
## EMD, Z+PC and Z-PC, no_sampling, imp
wtt = wt
mutt = mut


if True :
    dge_grandtotal = time.time()
    group='sub3'
    fname = '220330_mouse_imp_no_samp_ZPC' 
    dge = pd.DataFrame()
    for t in ['5wk','12wk','18wk','24wk','30wk'] :
        print('Evaluating {}'.format(t))
        t_total = time.time()
        dge_total = time.time()
        start_t=time.time()

        # up down dichotomy
        print('\n--------')
        print('...')
        print('--------\n')
        
        for i in ['Z+PC','Z-PC'] :
            start = time.time()
            print('\n{}, WT vs SCA1'.format(i))
            print('----')
            X = wtt[((wtt.obs[group]==i) & (wtt.obs['timepoint']==t)), :].layers['imputed']
            Y = mutt[((mutt.obs[group]==i) & (mutt.obs['timepoint']==t)), :].layers['imputed']
            

            X = np.asarray(X)
            Y = np.asarray(Y)
        
            print('    Ncells in X:{}'.format(X.shape[0]))
            print('    Ncells in Y:{}\n'.format(Y.shape[0]))            
            
            emd = scprep.stats.differential_expression(X,Y,
                                                       measure = 'emd',
                                                       direction='both',
                                                       gene_names=wtt.var_names,
                                                       n_jobs=-1)
            
            # mann-whitney u, corrected p-values
            p = mwu(X,Y,wtt.var_names)
            emd['Gene']=emd.index
            emd=emd.drop(columns='rank')
            fc = log2aveFC(Y,X,wtt.var_names.to_list())
            gene_mismatch = fc['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                fc = fc.loc[gene_mismatch,:]
                warnings.warn('Warning: {} genes dropped due to p-val NA.'.format((gene_mismatch==False).sum()))
            dt = pd.merge(p,fc,how='left',on="Gene")
            gene_mismatch = emd['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                emd = emd.loc[gene_mismatch,:]
            dt = pd.merge(dt,emd,how='left',on='Gene')
            dt['Cell type']=[i]*dt.shape[0]
            dt['timepoint']=[str(t)]*dt.shape[0]
            dt['nlog10pvalcorrected']=(-1)*np.log10(dt['pval_corrected'])
            dge = dge.append(dt, ignore_index=True)
            
            print('... computed in {:.2f}-s'.format(time.time()-start))
        print('\nFinished timepoint {} in {:.2f}-min'.format(t,(time.time()-start_t)/60))            
    dgeup = dge.loc[dge['emd']>0,:] # take only 'up' (switch for down)
    dgedown = dge.loc[dge['emd']<0,:] # take only 'down'    
    dgeup.to_csv(os.path.join(pfp,'dge_'+fname+'_WTup.csv'),index=False)
    dgedown.to_csv(os.path.join(pfp,'dge_'+fname+'_WTdown.csv'),index=False)


    print('DGE finished in {:.2f}-min'.format((time.time()-dge_grandtotal)/60))
# Out:
# Evaluating 5wk
#
# --------
# ...
# --------
#
#
# Z+PC, WT vs SCA1
# ----
#     Ncells in X:154
#     Ncells in Y:98
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.44-s
# ... 50% completed in 31.45-s
# ... 75% completed in 51.97-s
# ... mwu computed in 75.67-s
#
# ... computed in 86.48-s
#
# Z-PC, WT vs SCA1
# ----
#     Ncells in X:62
#     Ncells in Y:104
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.21-s
# ... 50% completed in 31.14-s
# ... 75% completed in 51.62-s
# ... mwu computed in 75.43-s
#
# ... computed in 78.74-s
#
# Finished timepoint 5wk in 2.75-min
# Evaluating 12wk
#
# --------
# ...
# --------
#
#
# Z+PC, WT vs SCA1
# ----
#     Ncells in X:90
#     Ncells in Y:59
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.20-s
# ... 50% completed in 31.11-s
# ... 75% completed in 51.53-s
# ... mwu computed in 75.23-s
#
# ... computed in 78.58-s
#
# Z-PC, WT vs SCA1
# ----
#     Ncells in X:22
#     Ncells in Y:32
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.01-s
# ... 50% completed in 30.72-s
# ... 75% completed in 51.07-s
# ... mwu computed in 74.84-s
#
# ... computed in 77.94-s
#
# Finished timepoint 12wk in 2.61-min
# Evaluating 18wk
#
# --------
# ...
# --------
#
#
# Z+PC, WT vs SCA1
# ----
#     Ncells in X:361
#     Ncells in Y:139
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 15.03-s
# ... 50% completed in 32.78-s
# ... 75% completed in 54.09-s
# ... mwu computed in 78.73-s
#
# ... computed in 82.76-s
#
# Z-PC, WT vs SCA1
# ----
#     Ncells in X:100
#     Ncells in Y:263
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.65-s
# ... 50% completed in 31.99-s
# ... 75% completed in 52.89-s
# ... mwu computed in 77.11-s
#
# ... computed in 80.75-s
#
# Finished timepoint 18wk in 2.73-min
# Evaluating 24wk
#
# --------
# ...
# --------
#
#
# Z+PC, WT vs SCA1
# ----
#     Ncells in X:83
#     Ncells in Y:67
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.21-s
# ... 50% completed in 31.09-s
# ... 75% completed in 51.51-s
# ... mwu computed in 75.29-s
#
# ... computed in 78.69-s
#
# Z-PC, WT vs SCA1
# ----
#     Ncells in X:62
#     Ncells in Y:47
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.03-s
# ... 50% completed in 30.73-s
# ... 75% completed in 50.96-s
# ... mwu computed in 74.57-s
#
# ... computed in 77.72-s
#
# Finished timepoint 24wk in 2.61-min
# Evaluating 30wk
#
# --------
# ...
# --------
#
#
# Z+PC, WT vs SCA1
# ----
#     Ncells in X:157
#     Ncells in Y:126
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.50-s
# ... 50% completed in 31.72-s
# ... 75% completed in 52.40-s
# ... mwu computed in 76.15-s
#
# ... computed in 79.70-s
#
# Z-PC, WT vs SCA1
# ----
#     Ncells in X:46
#     Ncells in Y:102
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.20-s
# ... 50% completed in 31.10-s
# ... 75% completed in 51.53-s
# ... mwu computed in 75.28-s
#
# ... computed in 78.68-s
#
# Finished timepoint 30wk in 2.64-min
# DGE finished in 13.37-min

# %%
## EMD; SUB4, IMP, Sampling, PC only

if True :
    dge_grandtotal = time.time()
    group='sub4'
    fname = '220401_mouse_imp_samp_PC' 
    dge = pd.DataFrame()
    for t in ['5wk','12wk','18wk','24wk','30wk'] :
        print('Evaluating {}'.format(t))
        t_total = time.time()
        dge_total = time.time()
        start_t=time.time()
        
        # up down dichotomy
        print('\n--------')
        print('...')
        print('--------\n')
#        dge = pd.DataFrame()
        for i in ['PC'] :
            start = time.time()
            print('\n{}, WT vs SCA1'.format(i))
            print('----')
            X = wt[((wt.obs[group]==i) & (wt.obs['timepoint']==t)), :].layers['imputed']
            Y = mut[((mut.obs[group]==i) & (mut.obs['timepoint']==t)), :].layers['imputed']
            

            X = np.asarray(X)
            Y = np.asarray(Y)
        
            print('    Ncells in X:{}'.format(X.shape[0]))
            print('    Ncells in Y:{}\n'.format(Y.shape[0]))            
            
            emd = scprep.stats.differential_expression(X,Y,
                                                       measure = 'emd',
                                                       direction='both',
                                                       gene_names=wt.var_names,
                                                       n_jobs=-1)
            
            # mann-whitney u, corrected p-values
            p = mwu(X,Y,wt.var_names)
            emd['Gene']=emd.index
            emd=emd.drop(columns='rank')
            fc = log2aveFC(Y,X,wt.var_names.to_list())
            gene_mismatch = fc['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                fc = fc.loc[gene_mismatch,:]
                warnings.warn('Warning: {} genes dropped due to p-val NA.'.format((gene_mismatch==False).sum()))
            dt = pd.merge(p,fc,how='left',on="Gene")
            gene_mismatch = emd['Gene'].isin(p['Gene'])
            if gene_mismatch.any():
                emd = emd.loc[gene_mismatch,:]
            dt = pd.merge(dt,emd,how='left',on='Gene')
            dt['Cell type']=[i]*dt.shape[0]
            dt['timepoint']=[str(t)]*dt.shape[0]
            dt['nlog10pvalcorrected']=(-1)*np.log10(dt['pval_corrected'])
            dge = dge.append(dt, ignore_index=True)
            print('... computed in {:.2f}-s'.format(time.time()-start))
        print('\nFinished timepoint {} in {:.2f}-min'.format(t,(time.time()-start_t)/60))  
#     dgeup = dge.loc[dge['emd']>0,:] # take only 'up' (switch for down)
#     dgedown = dge.loc[dge['emd']<0,:] # take only 'down'
#     dgeup.to_csv(os.path.join(pfp,'dge_'+fname+'_WTup.csv'),index=False)
#     dgedown.to_csv(os.path.join(pfp,'dge_'+fname+'_WTdown.csv'),index=False)
    dge.to_csv(os.path.join(pfp,'dge_'+fname+'.csv'),index=False)

        

    print('DGE finished in {:.2f}-min'.format((time.time()-dge_grandtotal)/60))
# Out:
# Evaluating 5wk
#
# --------
# ...
# --------
#
#
# PC, WT vs SCA1
# ----
#     Ncells in X:133
#     Ncells in Y:195
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.51-s
# ... 50% completed in 31.61-s
# ... 75% completed in 52.27-s
# ... mwu computed in 76.40-s
#
# ... computed in 109.77-s
#
# Finished timepoint 5wk in 1.83-min
# Evaluating 12wk
#
# --------
# ...
# --------
#
#
# PC, WT vs SCA1
# ----
#     Ncells in X:112
#     Ncells in Y:89
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.23-s
# ... 50% completed in 31.15-s
# ... 75% completed in 51.63-s
# ... mwu computed in 75.44-s
#
# ... computed in 78.61-s
#
# Finished timepoint 12wk in 1.31-min
# Evaluating 18wk
#
# --------
# ...
# --------
#
#
# PC, WT vs SCA1
# ----
#     Ncells in X:157
#     Ncells in Y:140
#
# Mann-Whitney U w/Benjamini/Hochberg correction
#
# ... 25% completed in 14.46-s
# ... 50% completed in 31.59-s
